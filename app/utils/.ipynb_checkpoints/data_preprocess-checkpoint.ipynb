# %%
import pandas as pd

# %%
hotels = pd.read_csv("../../datasets/hotels_athens.csv")
reviews = pd.read_csv("../../datasets/reviews_athens.csv")

# %% [markdown]
# ### Preprocess 'hotels_athens.csv'

# %%
hotels.head()
# Out:
#                       place_id                   name  rating  \
# 0  ChIJYbMf-s-joRQRrfrtIL4BKQo             LoftLiving     NaN
# 1  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments     4.7
# 2  ChIJiXeczKukoRQR5As1xN5u7Yo              NEFELI SA     NaN
# 3  ChIJiXeczKukoRQRP-j3EeDy8Rc       ΑΠΕΡΑΝΤΟ ΓΑΛΑΖΙΟ     5.0
# 4  ChIJm9S4QVSjoRQR6fPtkkjJ_8I         Camping Athens     3.4
#
#                             address
# 0    Agias Grigorousas 42, Chaidari
# 1                Pipinou 45, Athina
# 2             Aidiniou 21, Chaidari
# 3             Aidiniou 21, Chaidari
# 4  Leoforos Athinon 198-200, Athina

# %%
hotels.count()
# Out:
# place_id    2645
# name        2645
# rating      1848
# address     2644
# dtype: int64

# %%
hotels.duplicated().value_counts()
# Out:
# True     1379
# False    1266
# Name: count, dtype: int64

# %%
hotels.drop_duplicates(inplace=True)
hotels.dropna(inplace=True)
hotels.count()
# Out:
# place_id    874
# name        874
# rating      874
# address     874
# dtype: int64

# %% [markdown]
# ### Preprocess 'reviews_athens.csv'

# %%
reviews.head()
# Out:
#                       place_id        author_name  rating  \
# 0  ChIJXa9EhZajoRQRvI6l9_rat1U       Arthur Quing       5
# 1  ChIJXa9EhZajoRQRvI6l9_rat1U              M. K.       5
# 2  ChIJXa9EhZajoRQRvI6l9_rat1U   Stefhanie de Kom       5
# 3  ChIJXa9EhZajoRQRvI6l9_rat1U       yoel guenine       5
# 4  ChIJXa9EhZajoRQRvI6l9_rat1U  Kostas Gontikakis       5
#
#                                                 text           time
# 0  Feels like I'm home. Our family loves the swim...     a year ago
# 1  This is a hidden gem in the city. Great overni...  10 months ago
# 2  Very nice people. I was there just to visit my...    4 years ago
# 3                  Amazing appartment full equipped.    3 years ago
# 4                          The best place in Athens!    3 years ago

# %%
reviews.count()
# Out:
# place_id       7506
# author_name    7506
# rating         7506
# text           6618
# time           7506
# dtype: int64

# %%
reviews.duplicated().value_counts()
# Out:
# True     3986
# False    3520
# Name: count, dtype: int64

# %%
reviews.drop_duplicates(inplace=True)
reviews.dropna(inplace=True)
reviews.count()
# Out:
# place_id       3072
# author_name    3072
# rating         3072
# text           3072
# time           3072
# dtype: int64
