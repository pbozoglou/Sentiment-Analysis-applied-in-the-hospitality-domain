# %%
import pandas as pd

# %%
reviews = pd.read_csv("../../datasets/reviews_athens.csv")

# %% [markdown]
# ### Preprocess 'reviews_athens.csv'

# %%
reviews.head()
# Out:
#                       place_id             place_name  place_rating  \
# 0  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments           4.7
# 1  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments           4.7
# 2  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments           4.7
# 3  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments           4.7
# 4  ChIJXa9EhZajoRQRvI6l9_rat1U  ChrisAndro Apartments           4.7
#
#         place_address                                        place_types  \
# 0  Pipinou 45, Athina  ['lodging', 'point_of_interest', 'establishment']
# 1  Pipinou 45, Athina  ['lodging', 'point_of_interest', 'establishment']
# 2  Pipinou 45, Athina  ['lodging', 'point_of_interest', 'establishment']
# 3  Pipinou 45, Athina  ['lodging', 'point_of_interest', 'establishment']
# 4  Pipinou 45, Athina  ['lodging', 'point_of_interest', 'establishment']
#
#    location.lat  location.lng  place_user_ratings_total          user_name  \
# ...

# %%
reviews.count()
# Out:
# place_id                    5623
# place_name                  5623
# place_rating                5623
# place_address               5622
# place_types                 5623
# location.lat                5623
# location.lng                5623
# place_user_ratings_total    5623
# user_name                   5623
# user_rating                 5623
# review_text                 5623
# creation_time               5623
# dtype: int64

# %%
reviews.duplicated().value_counts()
# Out:
# False    5623
# Name: count, dtype: int64

# %%
reviews.dropna(subset='review_text',inplace=True)
reviews.count()
# Out:
# place_id                    5623
# place_name                  5623
# place_rating                5623
# place_address               5622
# place_types                 5623
# location.lat                5623
# location.lng                5623
# place_user_ratings_total    5623
# user_name                   5623
# user_rating                 5623
# review_text                 5623
# creation_time               5623
# dtype: int64

# %% [markdown]
# #### Analyzing dataset

# %%
'Average Rating:',reviews['user_rating'].sum()/reviews['user_rating'].count()
# Out:
# ('Average Rating:', 4.329895073804019)

# %%
reviews['review_text'].apply(len).mean()
# Out:
# 363.8641294682554

# %%
reviews[reviews['user_rating'] >= 4].count()['user_rating']
# Out:
# 4621

# %%
reviews[reviews['user_rating'] == 3].count()['user_rating']
# Out:
# 323

# %%
reviews[reviews['user_rating'] < 3].count()['user_rating']
# Out:
# 679

# %%
reviews.boxplot(column='user_rating')
# Out:
# <Axes: >
