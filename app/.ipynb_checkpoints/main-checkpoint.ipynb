# %% [markdown]
# # NLP PROJECT: Sentiment Analysis for domain-specific texts

# %% [markdown]
# **[[📑Project Description](https://eclass.uniwa.gr/modules/document/file.php/MSCAIVC107/%CE%95%CF%81%CE%B3%CE%B1%CF%83%CE%AF%CE%B1/MSc-AIVC%20NLP%20%CE%B5%CF%81%CE%B3%CE%B1%CF%83%CE%AF%CE%B1%202024-2025.pdf)][[🔗Github](https://github.com/pbozoglou/UNIWA-NLP-PROJECT)]**

# %% [markdown]
# ## Milestones
# - [Domain Selection and Dataset Creation](#Domain-Selection-and-Dataset-Creation)
# - [Preprocessing](#Preprocessing-and-Text-Analysis)
# - [Baseline Model Development](#Baseline-Model-Development)
# - [Deep Learning Model Development](#Deep-Learning-Model-Development)
# - [Evaluation, Performance Analysis and Visualization](#Evaluation,-Performance-Analysis-and-Visualization)

# %% [markdown]
# ## Domain Selection and Dataset Creation

# %% [markdown]
# The domain selected for this project is hotel reviews. Specifically, a dataset of reviews for lodgings in Athens city, created using the Google Places API.

# %%
import nltk
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', 15)

# %%
reviews = pd.read_csv("../datasets/reviews_athens.csv")
reviews.head()
# Out:
#          place_id      place_name  place_rating   place_address  \
# 0  ChIJXa9EhZa...  ChrisAndro ...           4.7  Pipinou 45,...
# 1  ChIJXa9EhZa...  ChrisAndro ...           4.7  Pipinou 45,...
# 2  ChIJXa9EhZa...  ChrisAndro ...           4.7  Pipinou 45,...
# 3  ChIJXa9EhZa...  ChrisAndro ...           4.7  Pipinou 45,...
# 4  ChIJXa9EhZa...  ChrisAndro ...           4.7  Pipinou 45,...
#
#       place_types  location.lat  location.lng  place_user_ratings_total  \
# 0  ['lodging',...     38.013307     23.677931              55
# 1  ['lodging',...     38.013307     23.677931              55
# 2  ['lodging',...     38.013307     23.677931              55
# 3  ['lodging',...     38.013307     23.677931              55
# 4  ['lodging',...     38.013307     23.677931              55
#
#         user_name  user_rating     review_text  creation_time
# 0    Arthur Quing            5  Feels like ...     1682362247
# 1           M. K.            5  This is a h...     1704966677
# ...

# %% [markdown]
# ## Preprocessing and Text Analysis

# %%
reviews_df = reviews.copy()

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5623 entries, 0 to 5622
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   place_id                  5623 non-null   object
#  1   place_name                5623 non-null   object
#  2   place_rating              5623 non-null   float64
#  3   place_address             5622 non-null   object
#  4   place_types               5623 non-null   object
#  5   location.lat              5623 non-null   float64
#  6   location.lng              5623 non-null   float64
#  7   place_user_ratings_total  5623 non-null   int64
#  8   user_name                 5623 non-null   object
#  9   user_rating               5623 non-null   int64
#  10  review_text               5623 non-null   object
#  11  creation_time             5623 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 527.3+ KB

# %% [markdown]
# **Drop duplicate & missing values (only 1 row will be affected for this dataset):**

# %%
reviews_df.drop_duplicates(inplace=True)
reviews_df.dropna(inplace=True)

# %% [markdown]
# **Convert to *positive* and *negative* sentiment:**

# %%
_, ax1 = plt.subplots(nrows=1,ncols=2,figsize=(8,3))

reviews_df['sentiment'] = 'neutral'
reviews_df.loc[reviews_df['user_rating'] < 3,'sentiment'] = 'negative'
reviews_df.loc[reviews_df['user_rating'] > 3,'sentiment'] = 'positive'
reviews_df.drop(index=reviews_df[reviews_df['sentiment']=='neutral'].index, inplace=True)

t1='Average Rating: {}'.format(round(reviews_df['user_rating'].mean(),2))
reviews_df['sentiment'].value_counts(True).plot(kind='bar',ax=ax1[0],subplots=True,rot=0)
reviews_df['user_rating'].plot(kind='hist',ax=ax1[1],subplots=True)
ax1[0].set_xlabel('')
ax1[0].set_ylabel('%')
ax1[0].set_title('Sentiment Distribution')
ax1[1].set_ylabel('')
ax1[1].set_title('Avg Rating: {}'.format(reviews_df.user_rating.mean().round(1)));

# %% [markdown]
# **⚠️ Note:** Positive ratings are dominant (more than 80% of the data)

# %% [markdown]
# **Randomly drop positive-sentiment rows to have a 1:1 distribution**

# %%
np.random.seed(42)

dx = reviews_df.sentiment.value_counts().positive - reviews_df.sentiment.value_counts().negative
random_positives_index = np.random.choice(reviews_df[reviews_df.sentiment=='positive'].index, dx, replace=False)

dataset = reviews_df.drop(index=random_positives_index)
dataset.head()[['review_text','sentiment']]
# Out:
#        review_text sentiment
# 4   The best pl...  positive
# 6   Total lack ...  negative
# 8   The camping...  negative
# 9   Our experie...  negative
# 12  Great hospi...  positive

# %% [markdown]
# **Explore the dataset**

# %%
_, ax2 = plt.subplots(nrows=1,ncols=3,figsize=(12,3))

dataset.sentiment.value_counts(True).plot(kind='bar',ax=ax2[0],subplots=True,rot=0)
dataset.review_text.apply(len).plot(kind='hist',ax=ax2[1],subplots=True)
dataset.user_rating.plot(kind='hist',ax=ax2[2],subplots=True)
ax2[0].set_title('Sentiment Distribution')
ax2[0].set_xlabel('')
ax2[0].set_ylabel('%')
ax2[1].set_title('Avg Char Len: {}'.format(dataset.review_text.apply(len).mean().round(1)))
ax2[1].set_ylabel('')
ax2[2].set_ylabel('')
ax2[2].set_title('Avg Rating: {}'.format(reviews_df_new.user_rating.mean().round(1)));

# %% [markdown]
# **Perform text cleaning: remove noise, handle emojis, stop words, and other irrelevant tokens.**

# %%
def clean(txt):
    txt = re.sub(r'\n',' ',txt).lower()
    return re.sub(r'\s\s+|[^\w\s.,!?]', '', txt)

# %%
sent0 = dataset.iloc[1262]['review_text']
sent0
# Out:
# '++ high tech room, clean and big room, polite staff, near to Acropole ( 30 minutes by foot), parking on the street or 10 eur per day if you wish safe parking lot.\nCofee capsules, tea, water on the room\nCleaning was done every day\nLuxury shower gel, towels.\nBest accommodation , I recommend them\nPrice / value 👌  perfect\nSmall market at 5 minutes\nElevator for luggage\nThis accommodation have everything that you need. The best 👌!!'

# %%
clean(sent0)
# Out:
# ' high tech room, clean and big room, polite staff, near to acropole  30 minutes by foot, parking on the street or 10 eur per day if you wish safe parking lot. cofee capsules, tea, water on the room cleaning was done every day luxury shower gel, towels. best accommodation , i recommend them price  value perfect small market at 5 minutes elevator for luggage this accommodation have everything that you need. the best !!'

# %%
len(clean(sent0))
# Out:
# 420

# %%
df = dataset.copy()
df['cleaned_review_text'] = df['review_text'].apply(clean)

# %% [markdown]
# **Average length after cleaning**

# %%
df['cleaned_review_text'].apply(len).mean()
# Out:
# 448.28424153166424

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
positive_reviews = ' '.join(df[df['sentiment'] == 'positive']['cleaned_review_text'])
wordcloud = WordCloud(width=800, height=400).generate(positive_reviews)

plt.figure(figsize=(7,3))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Baseline Model Development

# %% [markdown]
# ## Deep Learning Model Development

# %% [markdown]
# ## Evaluation, Performance Analysis and Visualization
